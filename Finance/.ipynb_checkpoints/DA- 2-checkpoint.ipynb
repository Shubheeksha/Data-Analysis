# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('Financials.csv', encoding='unicode_escape')

# %%
df.head(10)
# Out:
#             Segment  Country     Product   Discount Band   Units Sold   \
# 0        Government   Canada   Carretera            None    $1,618.50
# 1        Government  Germany   Carretera            None    $1,321.00
# 2         Midmarket   France   Carretera            None    $2,178.00
# 3         Midmarket  Germany   Carretera            None      $888.00
# 4         Midmarket   Mexico   Carretera            None    $2,470.00
# 5        Government  Germany   Carretera            None    $1,513.00
# 6         Midmarket  Germany     Montana            None      $921.00
# 7  Channel Partners   Canada     Montana            None    $2,518.00
# 8        Government   France     Montana            None    $1,899.00
# 9  Channel Partners  Germany     Montana            None    $1,545.00
#
#    Manufacturing Price   Sale Price     Gross Sales   Discounts   \
# 0                $3.00       $20.00      $32,370.00        $-
# 1                $3.00       $20.00      $26,420.00        $-
# 2                $3.00       $15.00      $32,670.00        $-
# 3                $3.00       $15.00      $13,320.00        $-
# 4                $3.00       $15.00      $37,050.00        $-
# 5                $3.00      $350.00    $5,29,550.00        $-
# 6                $5.00       $15.00      $13,815.00        $-
# 7                $5.00       $12.00      $30,216.00        $-
# 8                $5.00       $20.00      $37,980.00        $-
# 9                $5.00       $12.00      $18,540.00        $-
#
#            Sales            COGS          Profit         Date  Month Number  \
# 0     $32,370.00      $16,185.00      $16,185.00   01/01/2014             1
# 1     $26,420.00      $13,210.00      $13,210.00   01/01/2014             1
# 2     $32,670.00      $21,780.00      $10,890.00   01/06/2014             6
# 3     $13,320.00       $8,880.00       $4,440.00   01/06/2014             6
# 4     $37,050.00      $24,700.00      $12,350.00   01/06/2014             6
# 5   $5,29,550.00    $3,93,380.00    $1,36,170.00   01/12/2014            12
# 6     $13,815.00       $9,210.00       $4,605.00   01/03/2014             3
# 7     $30,216.00       $7,554.00      $22,662.00   01/06/2014             6
# 8     $37,980.00      $18,990.00      $18,990.00   01/06/2014             6
# 9     $18,540.00       $4,635.00      $13,905.00   01/06/2014             6
#
#    Month Name   Year
# 0     January   2014
# 1     January   2014
# 2        June   2014
# 3        June   2014
# 4        June   2014
# 5    December   2014
# 6       March   2014
# 7        June   2014
# 8        June   2014
# 9        June   2014

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Segment                700 non-null    object
#  1   Country                700 non-null    object
#  2    Product               700 non-null    object
#  3    Discount Band         700 non-null    object
#  4    Units Sold            700 non-null    object
#  5    Manufacturing Price   700 non-null    object
#  6    Sale Price            700 non-null    object
#  7    Gross Sales           700 non-null    object
#  8    Discounts             700 non-null    object
#  9     Sales                700 non-null    object
#  10   COGS                  700 non-null    object
#  11   Profit                700 non-null    object
#  12  Date                   700 non-null    object
#  13  Month Number           700 non-null    int64
#  14   Month Name            700 non-null    object
#  15  Year                   700 non-null    int64
# dtypes: int64(2), object(14)
# memory usage: 87.6+ KB

# %%
df.shape
# Out:
# (700, 16)

# %%
df.iloc[88:132]
# Out:
#               Segment                   Country     Product   Discount Band   \
# 88         Government                   Germany         VTT             Low
# 89         Government                    Canada         VTT             Low
# 90         Enterprise  United States of America         VTT             Low
# 91         Enterprise                    France         VTT             Low
# 92     Small Business                   Germany         VTT             Low
# 93     Small Business                    Mexico         VTT             Low
# 94         Government                    Mexico         VTT             Low
# 95         Enterprise                    France         VTT             Low
# 96   Channel Partners  United States of America    Amarilla             Low
# 97          Midmarket                    France    Amarilla             Low
# 98         Enterprise                    Canada   Carretera             Low
# 99   Channel Partners                    Canada   Carretera             Low
# 100    Small Business                   Germany   Carretera             Low
# 101        Government                    France   Carretera             Low
# 102        Government                    Canada   Carretera             Low
# 103  Channel Partners  United States of America     Montana             Low
# 104        Government  United States of America     Montana             Low
# 105  Channel Partners                    Mexico     Montana             Low
# 106        Enterprise                    Mexico     Montana             Low
# 107         Midmarket                    Canada       Paseo             Low
# 108    Small Business                    France       Paseo             Low
# 109    Small Business                   Germany       Paseo             Low
# 110  Channel Partners  United States of America       Paseo             Low
# 111        Enterprise                    Mexico       Paseo             Low
# 112  Channel Partners                    Canada       Paseo             Low
# 113        Enterprise                   Germany       Paseo             Low
# 114        Enterprise                    Mexico       Paseo             Low
# 115  Channel Partners                    France       Paseo             Low
# 116    Small Business                    Canada       Paseo             Low
# 117        Government                    Canada       Paseo             Low
# 118        Enterprise                    Canada       Paseo             Low
# 119         Midmarket  United States of America       Paseo             Low
# 120        Government  United States of America       Paseo             Low
# 121  Channel Partners                    France       Paseo             Low
# 122  Channel Partners                    Mexico       Paseo             Low
# 123        Government  United States of America        Velo             Low
# 124        Government                   Germany        Velo             Low
# 125        Government                   Germany        Velo             Low
# 126        Enterprise                   Germany        Velo             Low
# 127        Enterprise                    Mexico        Velo             Low
# 128  Channel Partners                    France        Velo             Low
# 129        Government                    Mexico        Velo             Low
# 130  Channel Partners                    Mexico        Velo             Low
# 131        Enterprise                    Mexico         VTT             Low
#
#      Units Sold   Manufacturing Price   Sale Price      Gross Sales   \
# 88      $263.00               $250.00        $7.00        $1,841.00
# 89      $943.50               $250.00      $350.00     $3,30,225.00
# 90      $727.00               $250.00      $125.00       $90,875.00
# 91      $787.00               $250.00      $125.00       $98,375.00
# 92      $986.00               $250.00      $300.00     $2,95,800.00
# 93      $494.00               $250.00      $300.00     $1,48,200.00
# 94    $1,397.00               $250.00      $350.00     $4,88,950.00
# 95    $1,744.00               $250.00      $125.00     $2,18,000.00
# 96    $1,989.00               $260.00       $12.00       $23,868.00
# 97      $321.00               $260.00       $15.00        $4,815.00
# 98      $742.50                 $3.00      $125.00       $92,812.50
# 99    $1,295.00                 $3.00       $12.00       $15,540.00
# 100     $214.00                 $3.00      $300.00       $64,200.00
# 101   $2,145.00                 $3.00        $7.00       $15,015.00
# 102   $2,852.00                 $3.00      $350.00     $9,98,200.00
# 103   $1,142.00                 $5.00       $12.00       $13,704.00
# 104   $1,566.00                 $5.00       $20.00       $31,320.00
# 105     $690.00                 $5.00       $12.00        $8,280.00
# 106   $1,660.00                 $5.00      $125.00     $2,07,500.00
# 107   $2,363.00                $10.00       $15.00       $35,445.00
# 108     $918.00                $10.00      $300.00     $2,75,400.00
# 109   $1,728.00                $10.00      $300.00     $5,18,400.00
# 110   $1,142.00                $10.00       $12.00       $13,704.00
# 111     $662.00                $10.00      $125.00       $82,750.00
# 112   $1,295.00                $10.00       $12.00       $15,540.00
# 113     $809.00                $10.00      $125.00     $1,01,125.00
# 114   $2,145.00                $10.00      $125.00     $2,68,125.00
# 115   $1,785.00                $10.00       $12.00       $21,420.00
# 116   $1,916.00                $10.00      $300.00     $5,74,800.00
# 117   $2,852.00                $10.00      $350.00     $9,98,200.00
# 118   $2,729.00                $10.00      $125.00     $3,41,125.00
# 119   $1,925.00                $10.00       $15.00       $28,875.00
# 120   $2,013.00                $10.00        $7.00       $14,091.00
# 121   $1,055.00                $10.00       $12.00       $12,660.00
# 122   $1,084.00                $10.00       $12.00       $13,008.00
# 123   $1,566.00               $120.00       $20.00       $31,320.00
# 124   $2,966.00               $120.00      $350.00    $10,38,100.00
# 125   $2,877.00               $120.00      $350.00    $10,06,950.00
# 126     $809.00               $120.00      $125.00     $1,01,125.00
# 127   $2,145.00               $120.00      $125.00     $2,68,125.00
# 128   $1,055.00               $120.00       $12.00       $12,660.00
# 129     $544.00               $120.00       $20.00       $10,880.00
# 130   $1,084.00               $120.00       $12.00       $13,008.00
# 131     $662.00               $250.00      $125.00       $82,750.00
#
#        Discounts            Sales            COGS          Profit   \
# 88        $18.41        $1,822.59       $1,315.00         $507.59
# 89     $3,302.25     $3,26,922.75    $2,45,310.00      $81,612.75
# 90       $908.75       $89,966.25      $87,240.00       $2,726.25
# 91       $983.75       $97,391.25      $94,440.00       $2,951.25
# 92     $2,958.00     $2,92,842.00    $2,46,500.00      $46,342.00
# 93     $1,482.00     $1,46,718.00    $1,23,500.00      $23,218.00
# 94     $4,889.50     $4,84,060.50    $3,63,220.00    $1,20,840.50
# 95     $2,180.00     $2,15,820.00    $2,09,280.00       $6,540.00
# 96       $238.68       $23,629.32       $5,967.00      $17,662.32
# 97        $48.15        $4,766.85       $3,210.00       $1,556.85
# 98     $1,856.25       $90,956.25      $89,100.00       $1,856.25
# 99       $310.80       $15,229.20       $3,885.00      $11,344.20
# 100    $1,284.00       $62,916.00      $53,500.00       $9,416.00
# 101      $300.30       $14,714.70      $10,725.00       $3,989.70
# 102   $19,964.00     $9,78,236.00    $7,41,520.00    $2,36,716.00
# 103      $274.08       $13,429.92       $3,426.00      $10,003.92
# 104      $626.40       $30,693.60      $15,660.00      $15,033.60
# 105      $165.60        $8,114.40       $2,070.00       $6,044.40
# 106    $4,150.00     $2,03,350.00    $1,99,200.00       $4,150.00
# 107      $708.90       $34,736.10      $23,630.00      $11,106.10
# 108    $5,508.00     $2,69,892.00    $2,29,500.00      $40,392.00
# 109   $10,368.00     $5,08,032.00    $4,32,000.00      $76,032.00
# 110      $274.08       $13,429.92       $3,426.00      $10,003.92
# 111    $1,655.00       $81,095.00      $79,440.00       $1,655.00
# 112      $310.80       $15,229.20       $3,885.00      $11,344.20
# 113    $2,022.50       $99,102.50      $97,080.00       $2,022.50
# 114    $5,362.50     $2,62,762.50    $2,57,400.00       $5,362.50
# 115      $428.40       $20,991.60       $5,355.00      $15,636.60
# 116   $11,496.00     $5,63,304.00    $4,79,000.00      $84,304.00
# 117   $19,964.00     $9,78,236.00    $7,41,520.00    $2,36,716.00
# 118    $6,822.50     $3,34,302.50    $3,27,480.00       $6,822.50
# 119      $577.50       $28,297.50      $19,250.00       $9,047.50
# 120      $281.82       $13,809.18      $10,065.00       $3,744.18
# 121      $253.20       $12,406.80       $3,165.00       $9,241.80
# 122      $260.16       $12,747.84       $3,252.00       $9,495.84
# 123      $626.40       $30,693.60      $15,660.00      $15,033.60
# 124   $20,762.00    $10,17,338.00    $7,71,160.00    $2,46,178.00
# 125   $20,139.00     $9,86,811.00    $7,48,020.00    $2,38,791.00
# 126    $2,022.50       $99,102.50      $97,080.00       $2,022.50
# 127    $5,362.50     $2,62,762.50    $2,57,400.00       $5,362.50
# 128      $253.20       $12,406.80       $3,165.00       $9,241.80
# 129      $217.60       $10,662.40       $5,440.00       $5,222.40
# 130      $260.16       $12,747.84       $3,252.00       $9,495.84
# 131    $1,655.00       $81,095.00      $79,440.00       $1,655.00
#
#            Date  Month Number  Month Name   Year
# 88   01/03/2014             3       March   2014
# 89   01/04/2014             4       April   2014
# 90   01/06/2014             6        June   2014
# 91   01/06/2014             6        June   2014
# 92   01/09/2014             9   September   2014
# 93   01/10/2013            10     October   2013
# 94   01/10/2014            10     October   2014
# 95   01/11/2014            11    November   2014
# 96   01/09/2013             9   September   2013
# 97   01/11/2013            11    November   2013
# 98   01/04/2014             4       April   2014
# 99   01/10/2014            10     October   2014
# 100  01/10/2013            10     October   2013
# 101  01/11/2013            11    November   2013
# 102  01/12/2014            12    December   2014
# 103  01/06/2014             6        June   2014
# 104  01/10/2014            10     October   2014
# 105  01/11/2014            11    November   2014
# 106  01/11/2013            11    November   2013
# 107  01/02/2014             2    February   2014
# 108  01/05/2014             5         May   2014
# 109  01/05/2014             5         May   2014
# 110  01/06/2014             6        June   2014
# 111  01/06/2014             6        June   2014
# 112  01/10/2014            10     October   2014
# 113  01/10/2013            10     October   2013
# 114  01/10/2013            10     October   2013
# 115  01/11/2013            11    November   2013
# 116  01/12/2014            12    December   2014
# 117  01/12/2014            12    December   2014
# 118  01/12/2014            12    December   2014
# 119  01/12/2013            12    December   2013
# 120  01/12/2013            12    December   2013
# 121  01/12/2014            12    December   2014
# 122  01/12/2014            12    December   2014
# 123  01/10/2014            10     October   2014
# 124  01/10/2013            10     October   2013
# 125  01/10/2014            10     October   2014
# 126  01/10/2013            10     October   2013
# 127  01/10/2013            10     October   2013
# 128  01/12/2014            12    December   2014
# 129  01/12/2013            12    December   2013
# 130  01/12/2014            12    December   2014
# 131  01/06/2014             6        June   2014

# %%
df.isna().sum()
# Out:
# Segment                  0
# Country                  0
#  Product                 0
#  Discount Band           0
#  Units Sold              0
#  Manufacturing Price     0
#  Sale Price              0
#  Gross Sales             0
#  Discounts               0
#   Sales                  0
#  COGS                    0
#  Profit                  0
# Date                     0
# Month Number             0
#  Month Name              0
# Year                     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.columns = df.columns.str.strip()

# %%
dollar = ['Units Sold', 'Manufacturing Price', 'Sale Price', 'Gross Sales', 'Discounts', 'Sales', 'COGS', 'Profit']
for columns in dollar:
    df[columns] = df[columns].str.replace('$', '')

# %%
df['Discounts'] = df['Discounts'].replace('-', '0',regex = True)

# %%
for columns in dollar:
    df[columns] = df[columns].replace(',', '', regex = True)

# %%
df
# Out:
#               Segment                   Country      Product Discount Band  \
# 0          Government                    Canada   Carretera          None
# 1          Government                   Germany   Carretera          None
# 2           Midmarket                    France   Carretera          None
# 3           Midmarket                   Germany   Carretera          None
# 4           Midmarket                    Mexico   Carretera          None
# ..                ...                       ...          ...           ...
# 695    Small Business                    France    Amarilla          High
# 696    Small Business                    Mexico    Amarilla          High
# 697        Government                    Mexico     Montana          High
# 698        Government                    Canada       Paseo          High
# 699  Channel Partners  United States of America         VTT          High
#
#     Units Sold Manufacturing Price Sale Price  Gross Sales    Discounts  \
# 0     1618.50                3.00      20.00     32370.00          0
# 1     1321.00                3.00      20.00     26420.00          0
# 2     2178.00                3.00      15.00     32670.00          0
# 3      888.00                3.00      15.00     13320.00          0
# 4     2470.00                3.00      15.00     37050.00          0
# ..         ...                 ...        ...          ...          ...
# 695   2475.00              260.00     300.00    742500.00    111375.00
# 696    546.00              260.00     300.00    163800.00     24570.00
# 697   1368.00                5.00       7.00      9576.00      1436.40
# 698    723.00               10.00       7.00      5061.00       759.15
# 699   1806.00              250.00      12.00     21672.00      3250.80
#
#            Sales         COGS      Profit        Date  Month Number  \
# 0      32370.00     16185.00    16185.00   01/01/2014             1
# 1      26420.00     13210.00    13210.00   01/01/2014             1
# 2      32670.00     21780.00    10890.00   01/06/2014             6
# 3      13320.00      8880.00     4440.00   01/06/2014             6
# 4      37050.00     24700.00    12350.00   01/06/2014             6
# ..           ...          ...         ...         ...           ...
# 695   631125.00    618750.00    12375.00   01/03/2014             3
# 696   139230.00    136500.00     2730.00   01/10/2014            10
# 697     8139.60      6840.00     1299.60   01/02/2014             2
# 698     4301.85      3615.00      686.85   01/04/2014             4
# 699    18421.20      5418.00    13003.20   01/05/2014             5
#
#      Month Name  Year
# 0      January   2014
# 1      January   2014
# 2         June   2014
# 3         June   2014
# 4         June   2014
# ..          ...   ...
# 695      March   2014
# 696    October   2014
# 697   February   2014
# 698      April   2014
# 699        May   2014
#
# [700 rows x 16 columns]

# %%
cols = ['Units Sold', 'Manufacturing Price','Sale Price', 'Gross Sales', 'Discounts','Sales','COGS']
for columns in cols:
    df[columns] = df[columns].astype(float)

# %%
(df['Profit'] == '-').sum()
# Out:
# 5

# %%
df.loc[df['Profit'] == '-']
# Out:
#         Segment  Country     Product Discount Band  Units Sold  \
# 187  Enterprise   Mexico    Montana           Low       1138.0
# 189  Enterprise  Germany      Paseo           Low        795.0
# 193  Enterprise   France      Paseo           Low       2988.0
# 200  Enterprise   Mexico      Paseo           Low       1138.0
# 209  Enterprise   Mexico   Amarilla           Low       1074.0
#
#      Manufacturing Price  Sale Price  Gross Sales  Discounts     Sales  \
# 187                  5.0       125.0     142250.0     5690.0  136560.0
# 189                 10.0       125.0      99375.0     3975.0   95400.0
# 193                 10.0       125.0     373500.0    14940.0  358560.0
# 200                 10.0       125.0     142250.0     5690.0  136560.0
# 209                260.0       125.0     134250.0     5370.0  128880.0
#
#          COGS Profit        Date  Month Number  Month Name  Year
# 187  136560.0      -  01/12/2014            12   December   2014
# 189   95400.0      -  01/03/2014             3      March   2014
# 193  358560.0      -  01/07/2014             7       July   2014
# 200  136560.0      -  01/12/2014            12   December   2014
# 209  128880.0      -  01/04/2014             4      April   2014

# %%
df = df[df['Profit'] != '-']

# %%
df['Profit'] = df['Profit'].str.strip()

# %%
df['Profit'] = df['Profit'].replace(r'[()]','', regex = True)

# %%
df['Profit'] = df['Profit'].astype(float)

# %%
df.dtypes
# Out:
# Segment                 object
# Country                 object
# Product                 object
# Discount Band           object
# Units Sold             float64
# Manufacturing Price    float64
# Sale Price             float64
# Gross Sales            float64
# Discounts              float64
# Sales                  float64
# COGS                   float64
# Profit                 float64
# Date                    object
# Month Number             int64
# Month Name              object
# Year                     int64
# dtype: object

# %%
df['Date']= pd.to_datetime(df['Date'])

# %%
df.dtypes
# Out:
# Segment                        object
# Country                        object
# Product                        object
# Discount Band                  object
# Units Sold                    float64
# Manufacturing Price           float64
# Sale Price                    float64
# Gross Sales                   float64
# Discounts                     float64
# Sales                         float64
# COGS                          float64
# Profit                        float64
# Date                   datetime64[ns]
# Month Number                    int64
# Month Name                     object
# Year                            int64
# dtype: object

# %%
df = df.drop(['Month Number', 'Month Name', 'Year'],axis = 1)

# %% [markdown]
# **Country wise analysis**

# %%
country_grouped_df = df.groupby('Country').agg({'Sales':'sum', 'Profit': 'sum','Units Sold': 'sum','COGS': 'sum'}).reset_index()

# %%
country_grouped_df.head()
# Out:
#                     Country        Sales      Profit  Units Sold        COGS
# 0                    Canada  24887654.89  3858206.39    247428.5  21358426.0
# 1                    France  23995612.29  4032488.29    237943.0  20214591.5
# 2                   Germany  23409940.82  3961381.32    200699.0  19729552.0
# 3                    Mexico  20547352.11  3198923.11    199975.0  17639829.0
# 4  United States of America  25029830.18  3397345.68    232627.5  22034289.5

# %%
plt.figure(figsize = (10,6))
plt.title('Total sales in each Country')
bars = plt.bar('Country', 'Sales',data = country_grouped_df, width = 0.4)
plt.xlabel('Country')
plt.ylabel('Sales')
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, height, round(height, 2),
             ha='center', va='bottom')

# %% [markdown]
# **Highest sales has been in USA and Canada, lowest has been in Mexico**

# %%
bar_width = 0.3
plt.figure(figsize = (10,6))
plt.title('Total sales in each Country')
x = np.arange(len(country_grouped_df['Country']))
plt.bar(x-bar_width, country_grouped_df['Sales'], bar_width, label = 'Sales')
plt.bar(x, country_grouped_df['COGS'], bar_width, label = 'COGS')

plt.xticks(x, country_grouped_df['Country'])
plt.xlabel('Country')
plt.ylabel('Values')
plt.legend(loc='upper right')

# %% [markdown]
# **The Company is in profit as the Sales is more than COGS**

# %%
plt.figure(figsize = (10,6))
plt.title('Total profit in each Country')
bars = plt.bar('Country', 'Profit',data = country_grouped_df, width = 0.4)
plt.xlabel('Country')
plt.ylabel('Profit')
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, height, round(height, 2),
             ha='center', va='bottom')

# %%
plt.figure(figsize = (10,6))
plt.title('Total units sold in each Country')
bars = plt.bar('Country', 'Units Sold',data = country_grouped_df, width = 0.4)
plt.xlabel('Country')
plt.ylabel('Units Sold')
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, height, round(height, 2),
             ha='center', va='bottom')

# %% [markdown]
# **Company at France make the most profit despit USA making the most sales, the difference between Sales price and COGS is higher in France.**

# %%
plt.title('Country wise profit:')
plt.pie(country_grouped_df["Profit"], labels = country_grouped_df["Country"], autopct = '%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x2a1bf499040>,
#   <matplotlib.patches.Wedge at 0x2a1bea22480>,
#   <matplotlib.patches.Wedge at 0x2a1bf4cdac0>,
#   <matplotlib.patches.Wedge at 0x2a1bf4cec30>,
#   <matplotlib.patches.Wedge at 0x2a1bf4cf230>],
#  [Text(0.8709980441621259, 0.671835104073724, 'Canada'),
#   Text(-0.4584973421857824, 0.9998900875639151, 'France'),
#   Text(-1.0733839588596852, -0.24051377686675207, 'Germany'),
#   Text(-0.14371994098878643, -1.0905707581638984, 'Mexico'),
#   Text(0.9209891572307225, -0.6014806499493094, 'United States of America')],
#  [Text(0.4750898422702504, 0.36645551131294035, '20.9%'),
#   Text(-0.25008945937406313, 0.5453945932166808, '21.9%'),
#   Text(-0.5854821593780101, -0.1311893328364102, '21.5%'),
#   Text(-0.07839269508479259, -0.594856777180308, '17.3%'),
#   Text(0.5023577221258486, -0.3280803545178051, '18.4%')])

# %% [markdown]
# **Most profit is made by France**

# %% [markdown]
# **Product wise analysis**

# %%
plt.bar('Product', 'Gross Margin', data = product_grouped_df)
plt.title('Gross Margin of Products')
plt.xlabel('Product')
# Out:
# Text(0.5, 0, 'Product')

# %%
plt.title('Product wise profit')
plt.pie(product_grouped_df['Profit'],labels = product_grouped_df['Product'], autopct = '%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x2a1bf5132f0>,
#   <matplotlib.patches.Wedge at 0x2a1bf46fd10>,
#   <matplotlib.patches.Wedge at 0x2a1bf58cef0>,
#   <matplotlib.patches.Wedge at 0x2a1bf58d460>,
#   <matplotlib.patches.Wedge at 0x2a1bf58da60>,
#   <matplotlib.patches.Wedge at 0x2a1bf58e060>],
#  [Text(0.954191948116358, 0.5472821266494181, ' Amarilla '),
#   Text(0.1529518002191501, 1.0893143471054263, ' Carretera '),
#   Text(-0.6477731846139089, 0.8890387512899284, ' Montana '),
#   Text(-1.0520731099363954, -0.3211575491075394, ' Paseo '),
#   Text(0.1553808460717646, -1.0889705196533204, ' VTT '),
#   Text(0.9973629893323634, -0.4639688217003508, ' Velo ')],
#  [Text(0.5204683353361952, 0.29851752362695533, '16.6%'),
#   Text(0.08342825466499097, 0.5941714620575053, '12.4%'),
#   Text(-0.35333082797122295, 0.48493022797632446, '12.1%'),
#   Text(-0.5738580599653065, -0.17517684496774877, '27.3%'),
#   Text(0.08475318876641706, -0.5939839198109019, '17.8%'),
#   Text(0.5440161759994709, -0.25307390274564584, '13.9%')])

# %% [markdown]
# **Higest profit is from Paseo and lowest is from Montana.**

# %%
bar_width = 0.3
plt.figure(figsize = (10,6))
plt.title('Sales and COGS of products')
x = np.arange(len(product_grouped_df['Product']))
plt.bar(x-bar_width, product_grouped_df['Sales'], bar_width, label = 'Sales')
plt.bar(x, product_grouped_df['COGS'], bar_width, label = 'COGS')

plt.xticks(x, product_grouped_df['Product'])
plt.xlabel('Product')
plt.ylabel('Values')
plt.legend(loc='upper right')

# %%
plt.figure(figsize = (10,6))
plt.title('Total units sold of each product')
bars = plt.bar('Product', 'Units Sold',data = product_grouped_df, width = 0.4)
plt.xlabel('Product')
plt.ylabel('Units Sold')
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, height, round(height, 2),
             ha='center', va='bottom')

# %% [markdown]
# **Maximum sold product is Paseo**

# %% [markdown]
# **Segment wise analysis**

# %%
segment_grouped_df = df.groupby('Segment').agg({'Gross Sales':'sum', 'Sales':'sum', 'Profit': 'sum','Units Sold': 'sum','COGS': 'sum'}).reset_index()

# %%
plt.title('Segment wise profit:')
plt.pie(segment_grouped_df["Profit"], labels = segment_grouped_df["Segment"], autopct = '%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x2a1bfb55c70>,
#   <matplotlib.patches.Wedge at 0x2a1ba0588c0>,
#   <matplotlib.patches.Wedge at 0x2a1bfb564b0>,
#   <matplotlib.patches.Wedge at 0x2a1bfb56990>,
#   <matplotlib.patches.Wedge at 0x2a1bfb56fc0>],
#  [Text(1.0724596925827001, 0.24460214182508844, 'Channel Partners'),
#   Text(0.9025126424099973, 0.628864794920279, 'Enterprise'),
#   Text(-0.9981935843407128, 0.4621791516079456, 'Government'),
#   Text(0.05200580858749933, -1.0987699467464336, 'Midmarket'),
#   Text(0.8373838841919183, -0.7132939299444908, 'Small Business')],
#  [Text(0.5849780141360181, 0.13341935008641187, '7.1%'),
#   Text(0.4922796231327257, 0.34301716086560674, '5.1%'),
#   Text(-0.544469227822207, 0.2520977190588794, '61.7%'),
#   Text(0.02836680468409054, -0.599329061861691, '3.6%'),
#   Text(0.45675484592286447, -0.38906941633335856, '22.5%')])

# %% [markdown]
# **Government sector gives the most profit and Midmarket gives the least.**

# %%
bar_width = 0.3
plt.figure(figsize = (10,6))
plt.title('Sales and COGS of Segment')
x = np.arange(len(segment_grouped_df['Segment']))
plt.bar(x-bar_width, segment_grouped_df['Gross Sales'], bar_width, label = 'Sales')
plt.bar(x, segment_grouped_df['COGS'], bar_width, label = 'COGS')

plt.xticks(x, segment_grouped_df['Segment'])
plt.xlabel('Product')
plt.ylabel('Values')
plt.legend(loc='upper right')

# %%
plt.figure(figsize = (10,6))
plt.title('Total units sold by each segment')
bars = plt.bar('Segment', 'Units Sold',data =segment_grouped_df, width = 0.4)
plt.xlabel('Segment')
plt.ylabel('Units Sold')
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, height, round(height, 2),
             ha='center', va='bottom')

# %% [markdown]
# **Most units are sold in Government Segment and least in Small Business**

# %%
df.set_index('Date', inplace=True)
yearly_profit_df = df['Profit'].resample('YE').sum()

# %%
yearly_profit_df = yearly_profit_df.reset_index()

# %%
yearly_profit_df
# Out:
#         Date       Profit
# 0 2013-12-31   4323139.51
# 1 2014-12-31  14125205.28

# %%
yearly_profit_df['Date']= pd.to_datetime(yearly_profit_df['Date'])

# %%
plt.bar(yearly_profit_df['Date'].dt.year, 'Profit', data = yearly_profit_df)
# Out:
# <BarContainer object of 2 artists>
